# %%
import sys
import csv
import pandas as pd

# %%
data = sys.stdin.readlines('tabla')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-143e6e23ecb5> in <module>
# ----> 1 data = sys.stdin.readlines('tabla')
#
# TypeError: argument should be integer or None, not 'str'

# %%
tabla = csv.reader('credit.csv/')
tabla

# %%
# %%writefile mapper.py

import csv
if __name__ == "__main__":

    for line in csv.reader(sys.stdin.readlines()):
        
        word = line[2]
        
        sys.stdout.write("{}\t1\n".format(word))
# Out:
# Overwriting mapper.py

# %%
# !chmod +x mapper.py

# %%
# !read -r credit.csv | ./mapper.py | head
# Out:
# import-im6.q16: unable to grab mouse `': Recurso no disponible temporalmente @ error/xwindow.c/XSelectWindow/9181.
# ./mapper.py: 5: ./mapper.py: Syntax error: "(" unexpected

# %%
##
## Esta es la funcion que mapea la entrada a parejas (clave, valor)
##
import sys
import csv

if __name__ == "__main__":

    ##
    ## itera sobre cada linea de codigo recibida
    ## a traves del flujo de entrada
    ##
    for line in sys.stdin:

        ##
        ## genera las tuplas palabra \tabulador 1
        ## ya que es un conteo de palabras
        ##
        for word in line.split():

            ##
            ## escribe al flujo estandar de salida
            ##
            sys.stdout.write("{}\t1\n".format(word))

# %%
if __name__ == '__main__':

    curkey = None
    total = 0

  
    for line in sys.stdin:

        key, val = line.split("\t")
        val = int(val)

        if key == curkey:
         
            total += val
        else:
            ##
            ## Se cambio de clave. Se reinicia el
            ## acumulador.
            ##
            if curkey is not None:
                ##
                ## una vez se han reducido todos los elementos
                ## con la misma clave se imprime el resultado en
                ## el flujo de salida
                ##
                sys.stdout.write("{}\t{}\n".format(curkey, total))

            curkey = key
            total = val

    sys.stdout.write("{}\t{}\n".format(curkey, total))

# %%
dato = sys.stdin.readlines()
    for line in csv.reader(dato):

        purpose = line[3]
        ammount = line[4]

        sys.stdout.write("{}\{}\n".format(purpose, ammount))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-4238e9ee04ae> in <module>
#       7         sys.stdout.write("{}\{}\n".format(purpose, ammount))
#       8
# ----> 9 head
#
# NameError: name 'head' is not defined

# %%
dato= pd.read_csv('credit.csv')

# %%
dato
# Out:
#     checking_balance  months_loan_duration          credit_history  \
# 0             < 0 DM                     6                critical
# 1         1 - 200 DM                    48                  repaid
# 2            unknown                    12                critical
# 3             < 0 DM                    42                  repaid
# 4             < 0 DM                    24                 delayed
# 5            unknown                    36                  repaid
# 6            unknown                    24                  repaid
# 7         1 - 200 DM                    36                  repaid
# 8            unknown                    12                  repaid
# 9         1 - 200 DM                    30                critical
# 10        1 - 200 DM                    12                  repaid
# 11            < 0 DM                    48                  repaid
# 12        1 - 200 DM                    12                  repaid
# ...
